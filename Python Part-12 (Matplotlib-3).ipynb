# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
days = [1, 2, 3, 4, 5, 6, 7]

sleeping = [7, 7, 7, 7, 7, 9, 9]
eating = [2, 2, 2, 2, 2, 3, 3]
college_time = [8, 9, 8, 9, 8, 2, 2]
playing = [2, 2, 2, 2, 2, 4, 4]
self_learning = [1, 1, 1, 1, 1, 4, 4]

slices = [7, 3, 10, 3, 4]
activity = ['sleeping','eating','college_time','playing','self_learning']
color = ['c','m','r','y','b']

plt.pie(slices, labels=activity, colors=color, shadow=True, autopct='%1.1f%%')

plt.title('My Daily Life during College')
plt.show()
